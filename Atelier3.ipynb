# %%
import torch
import numpy as np

# %%
arr_np = np.array([1.0, 2.0, 3.0])
arr_torch = torch.tensor([1.0, 2.0, 3.0])

# %%
arr_np, arr_torch
# Out:
# (array([1., 2., 3.]), tensor([1., 2., 3.]))

# %%
torch.from_numpy(arr_np), arr_torch.numpy()
# Out:
# (tensor([1., 2., 3.], dtype=torch.float64), array([1., 2., 3.], dtype=float32))

# %%
zeros = torch.zeros(2,3)
ones = torch.ones(2,3)
rand = torch.randn(2,3)

print("\n[1.2] torch.zeros")

# %%
a = torch.tensor([[]])
